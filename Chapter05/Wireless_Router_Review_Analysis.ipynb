# %%
# !pip install wordcloud
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# !pip install textblob
from textblob import TextBlob
# Out:
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.7/dist-packages (1.5.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from wordcloud) (7.1.2)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.7/dist-packages (from wordcloud) (1.19.5)
# Requirement already satisfied: textblob in /usr/local/lib/python3.7/dist-packages (0.15.3)
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.7/dist-packages (from textblob) (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk>=3.1->textblob) (1.15.0)

# %%
df = pd.read_csv('Reviews.csv')
document = df['Reviews'].to_string()

# %%
wordcloud = WordCloud().generate(document)
plt.figure(figsize = (20,15))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
s = df['Reviews']
df['Reviews'] = df['Reviews'].astype(str)
df = df[df['Reviews'] == s]
df[['polarity', 'subjectivity']] = df['Reviews'].apply(lambda Text: pd.Series(TextBlob(Text).sentiment))

# %%
df[df['polarity'] < 0]
# Out:
#                                                Reviews  polarity  subjectivity
# 14                 Short range and not worth the money -0.075000      0.200000
# 21                     This router has a limited range -0.071429      0.142857
# 27                               Range is not very far -0.038462      0.769231
# 32                        Biggest con - hard to set up -0.291667      0.541667
# 57                       The router's range is limited -0.071429      0.142857
# 72                                The range is minimal -0.100000      0.600000
# 75                                        WIFI is slow -0.300000      0.400000
# 86                  A little bit of heat is acceptable -0.187500      0.500000
# 138                            It’s a little confusing -0.243750      0.450000
# 143                      Not worth it for an old house -0.025000      0.150000
# 189                         The range is not very good -0.269231      0.461538
# 191  The connection is a lot less stable than my ol... -0.033333      0.133333
# 199                What does it mean to be "wireless"? -0.312500      0.687500
# 206                     The device in less than 3 feet -0.166667      0.066667
# 232                                  Not a great range -0.400000      0.750000
# 233                                 Bad quality signal -0.700000      0.666667
# 243                        Poor signal in the basement -0.400000      0.600000
# 251                                   Extreme speed 5G -0.125000      1.000000
# 286                                No more dead zones! -0.250000      0.450000
# 294          I'm not sure how short range it is for me -0.125000      0.594444
# 300                                          I hate it -0.800000      0.900000
# 306         I need a wireless router with a long range -0.050000      0.400000
# 308                     This router is a waste of time -0.200000      0.000000
# 309                                      Limited Range -0.071429      0.142857
# 323             Only a few ports for wired connections -0.100000      0.550000
# 339  The range is not good and the design of the ro... -0.350000      0.600000
# 370        The router is great but the app is terrible -0.100000      0.875000
# 385                                      Lousy product -0.500000      0.500000
# 399                                       Not worth it -0.150000      0.100000
# 404                           Weak wireless connection -0.375000      0.625000
# 411                         I'm not sure what you mean -0.281250      0.788194
# 425                          Bad signal in living room -0.700000      0.666667
# 436                    If you're serious, buy this one -0.333333      0.666667
# 443                            Wifi speed is not great -0.400000      0.750000
# 467                                 The range is awful -1.000000      1.000000
# 479                                      Remote access -0.100000      0.200000
# 494                                       Not worth it -0.150000      0.100000
# 497                                     Less buffering -0.166667      0.066667
# 507                                 Heavily discounted -0.200000      0.500000
# 514                          Tired of your old router? -0.150000      0.450000
# 522                         It is actually a small box -0.250000      0.400000
# 551                             Not worth the headache -0.150000      0.100000
# 552                              The range is not good -0.350000      0.600000
# 554                    The signal is not strong enough -0.108333      0.616667
# 587                   The wireless coverage is limited -0.071429      0.142857
# 593         I need a wireless router with a long range -0.050000      0.400000
# 630                            Be careful not to drop! -0.125000      1.000000
# 667            It has a shorter range than we expected -0.100000      0.400000
# 671                             Not bad, but not great -0.025000      0.708333
# 672                          You won't be disappointed -0.750000      0.750000
# 683                                  It's not that bad -0.700000      0.666667
# 688            We have been using this for a long time -0.050000      0.400000
# 691                                       Not worth it -0.150000      0.100000
# 700                                      Hard to setup -0.291667      0.541667
# 715                                              Small -0.250000      0.400000
# 730                                         Long range -0.050000      0.400000
# 750                             1TB for less than $100 -0.166667      0.066667

# %%
df[(df['polarity'] > 0.2) & (df['subjectivity'] < 0.5)]
# Out:
#                                               Reviews  polarity  subjectivity
# 12                                   Worth the money.     0.300        0.1000
# 13                    It's a good, short range router     0.350        0.4500
# 19                                           The Best     1.000        0.3000
# 26                                           Best Buy     1.000        0.3000
# 53                                    One of the best     1.000        0.3000
# 71                           The best option for most     0.750        0.4000
# 106                                   The best router     1.000        0.3000
# 112               The router will be your best friend     1.000        0.3000
# 145                                   Worth the price     0.300        0.1000
# 147                            Can't be more specific     0.250        0.3125
# 163                          Fastest router available     0.400        0.4000
# 179                      Best router, good for gaming     0.850        0.4500
# 185                                  Good short range     0.350        0.4500
# 190                            Best option for gaming     1.000        0.3000
# 193                          This is the best router!     1.000        0.3000
# 207                         the range is not the best     1.000        0.3000
# 210                     The antennas are not the best     1.000        0.3000
# 230           The best wireless router I've ever used     1.000        0.3000
# 231                                   One of the best     1.000        0.3000
# 246                             The best rated router     1.000        0.3000
# 252                                     Best in Class     1.000        0.3000
# 277                                Yes, it's worth it     0.300        0.1000
# 293       It's a good router, but not for a big house     0.350        0.3500
# 297                           Best bang for the buck!     1.000        0.3000
# 312             This is the best router I've ever had     1.000        0.3000
# 320                          The best wireless router     1.000        0.3000
# 353                                          The best     1.000        0.3000
# 358                             Best wifi range ever!     1.000        0.3000
# 360                    The best options for your home     1.000        0.3000
# 386                               Best buy and update     1.000        0.3000
# 387                                       Best router     1.000        0.3000
# 408             For a short range, it does a good job     0.350        0.4500
# 415                              Best wireless router     1.000        0.3000
# 455        It's a good buy for a short range wireless     0.350        0.4500
# 456                                          The best     1.000        0.3000
# 461                   Best WiFi Router for the Money!     1.000        0.3000
# 474                           The Linksys is the best     1.000        0.3000
# 482                     The best router I've ever had     1.000        0.3000
# 516   What is the best wireless router for my family?     1.000        0.3000
# 546                         The best wireless router!     1.000        0.3000
# 566                            Best router for gaming     1.000        0.3000
# 588            I was able to connect multiple devices     0.250        0.3125
# 603                Overall a good router for home use     0.350        0.3000
# 608                                        Best Rated     1.000        0.3000
# 615                                    5G for the win     0.800        0.4000
# 619                It is a good device at a low price     0.350        0.4500
# 622                                 Totally worth it!     0.375        0.1000
# 629   Good for phone calls, not so much for streaming     0.450        0.4000
# 635                                          The best     1.000        0.3000
# 662                          Works well, not the best     1.000        0.3000
# 697              This router is the best router ever.     1.000        0.3000
# 699                            The best for the price     1.000        0.3000
# 704                         The best wireless router!     1.000        0.3000
# 728                                Best router ever!!     1.000        0.3000
# 737   It's good for streaming, not so much for gaming     0.450        0.4000
# 739                       The best buy for this model     1.000        0.3000
# 745                    My internet is so much faster!     0.250        0.2000
# 747                          The best wireless router     1.000        0.3000
# 755                    The best wireless router EVER!     1.000        0.3000
